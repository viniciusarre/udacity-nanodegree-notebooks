# %% [markdown]
# # STEP3: Perform some simple data analysis
#
# Start by connecting to the database by running the cells below. If you are coming back to this exercise, then uncomment and run the first cell to recreate the database. If you recently completed steps 1 and 2, then skip to the second cell.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-schema.sql
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-data.sql
# Out:
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %%
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# postgresql://student:student@127.0.0.1:5432/pagila
# 'Connected: student@pagila'

# %% [markdown]
# ### 3NF - Entity Relationship Diagram
#
# <img src="./pagila-3nf.png" width="50%"/>
#
# ## 3.1 Insight 1:   Top Grossing Movies
# - Payments amounts are in table `payment`
# - Movies are in table `film`
# - They are not directly linked, `payment` refers to a `rental`, `rental` refers to an `inventory` item and `inventory` item refers to a `film`
# - `payment` &rarr; `rental` &rarr; `inventory` &rarr; `film`

# %% [markdown]
# ### 3.1.1 Films

# %%
# %%sql
# select film_id, title, release_year, rental_rate, rating  from film limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 'ACADEMY DINOSAUR', 2006, Decimal('0.99'), 'PG'),
#  (2, 'ACE GOLDFINGER', 2006, Decimal('4.99'), 'G'),
#  (3, 'ADAPTATION HOLES', 2006, Decimal('2.99'), 'NC-17'),
#  (4, 'AFFAIR PREJUDICE', 2006, Decimal('2.99'), 'G'),
#  (5, 'AFRICAN EGG', 2006, Decimal('2.99'), 'G')]

# %% [markdown]
# ### 3.1.2 Payments

# %%
# %%sql
# select * from payment limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(16050, 269, 2, 7, Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16051, 269, 1, 98, Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16052, 269, 2, 678, Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16053, 269, 2, 703, Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (16054, 269, 1, 750, Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.3 Inventory

# %%
# %%sql
# select * from inventory limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (2, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (3, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (4, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None))),
#  (5, 1, 2, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)))]

# %% [markdown]
# ### 3.1.4 Get the movie of every payment

# %%
# %%sql
# SELECT f.title, p.amount, p.payment_date, p.customer_id
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# limit 5;

# %% [markdown]
# ### 3.1.5 sum movie rental revenue
# TODO: Write a query that displays the amount of revenue from each title. Limit the results to the top 10 grossing titles. Your results should match the table below.

# %%
# %%sql
# SELECT f.title, SUM(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# GROUP BY f.title
# ORDER BY revenue DESC
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('TELEGRAPH VOYAGE', Decimal('231.73')),
#  ('WIFE TURN', Decimal('223.69')),
#  ('ZORRO ARK', Decimal('214.69')),
#  ('GOODFELLAS SALUTE', Decimal('209.69')),
#  ('SATURDAY LAMBS', Decimal('204.72')),
#  ('TITANS JERK', Decimal('201.71')),
#  ('TORQUE BOUND', Decimal('198.72')),
#  ('HARRY IDAHO', Decimal('195.70')),
#  ('INNOCENT USUAL', Decimal('191.74')),
#  ('HUSTLER PARTY', Decimal('190.78'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>title</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>TELEGRAPH VOYAGE</td>
#         <td>231.73</td>
#     </tr>
#     <tr>
#         <td>WIFE TURN</td>
#         <td>223.69</td>
#     </tr>
#     <tr>
#         <td>ZORRO ARK</td>
#         <td>214.69</td>
#     </tr>
#     <tr>
#         <td>GOODFELLAS SALUTE</td>
#         <td>209.69</td>
#     </tr>
#     <tr>
#         <td>SATURDAY LAMBS</td>
#         <td>204.72</td>
#     </tr>
#     <tr>
#         <td>TITANS JERK</td>
#         <td>201.71</td>
#     </tr>
#     <tr>
#         <td>TORQUE BOUND</td>
#         <td>198.72</td>
#     </tr>
#     <tr>
#         <td>HARRY IDAHO</td>
#         <td>195.70</td>
#     </tr>
#     <tr>
#         <td>INNOCENT USUAL</td>
#         <td>191.74</td>
#     </tr>
#     <tr>
#         <td>HUSTLER PARTY</td>
#         <td>190.78</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## 3.2 Insight 2:   Top grossing cities
# - Payments amounts are in table `payment`
# - Cities are in table `cities`
# - `payment` &rarr; `customer` &rarr; `address` &rarr; `city`

# %% [markdown]
# ### 3.2.1 Get the city of each payment

# %%
# %%sql
# SELECT ci.city, p.amount as revenue
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# GROUP BY ci.city, p.amount
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 4804 rows affected.
# [('Basel', Decimal('0.99')),
#  ('Cuman', Decimal('7.99')),
#  ('Erlangen', Decimal('5.99')),
#  ('Iwaki', Decimal('2.99')),
#  ('Kolpino', Decimal('3.99')),
#  ('Pangkal Pinang', Decimal('2.99')),
#  ('Tama', Decimal('7.99')),
#  ('Kolpino', Decimal('6.99')),
#  ('Bandar Seri Begawan', Decimal('5.99')),
#  ('Bag', Decimal('2.99')),
#  ('Kimchon', Decimal('0.99')),
#  ('Jinchang', Decimal('10.99')),
#  ('Cavite', Decimal('0.99')),
#  ('Ziguinchor', Decimal('7.99')),
#  ('Citrus Heights', Decimal('0.99')),
#  ('Tychy', Decimal('1.99')),
#  ('Jhansi', Decimal('4.99')),
#  ('Maikop', Decimal('0.99')),
#  ('Nha Trang', Decimal('7.99')),
#  ('Saarbrcken', Decimal('4.99')),
#  ('Hagonoy', Decimal('8.99')),
#  ('al-Qatif', Decimal('4.99')),
#  ('Nyeri', Decimal('8.99')),
#  ('Patras', Decimal('2.99')),
#  ('Nagareyama', Decimal('9.99')),
#  ('Deba Habe', Decimal('7.99')),
#  ('Shikarpur', Decimal('5.99')),
#  ('Braslia', Decimal('4.99')),
#  ('Ezeiza', Decimal('3.99')),
#  ('Bucuresti', Decimal('1.99')),
#  ('Cam Ranh', Decimal('5.99')),
#  ('Fengshan', Decimal('1.99')),
#  ('Abha', Decimal('0.99')),
#  ('Ljubertsy', Decimal('6.99')),
#  ('Alessandria', Decimal('5.99')),
#  ('Ljubertsy', Decimal('3.99')),
#  ('Augusta-Richmond County', Decimal('0.99')),
#  ('Konotop', Decimal('0.99')),
#  ('Tongliao', Decimal('4.99')),
#  ('Berhampore (Baharampur)', Decimal('5.99')),
#  ('Koriyama', Decimal('1.99')),
#  ('Ranchi', Decimal('0.99')),
#  ('Omiya', Decimal('10.99')),
#  ('Huaian', Decimal('3.99')),
#  ('Allende', Decimal('2.99')),
#  ('Linz', Decimal('0.99')),
#  ('Tarsus', Decimal('2.99')),
#  ('al-Hawiya', Decimal('9.99')),
#  ('Boksburg', Decimal('4.99')),
#  ('Tegal', Decimal('1.99')),
#  ('Rockford', Decimal('10.99')),
#  ('Mwanza', Decimal('3.99')),
#  ('Mwanza', Decimal('6.99')),
#  ('So Leopoldo', Decimal('8.99')),
#  ('Vilnius', Decimal('0.99')),
#  ('Aurora', Decimal('0.99')),
#  ('Zalantun', Decimal('4.99')),
#  ('Bergamo', Decimal('5.99')),
#  ('Kurashiki', Decimal('0.99')),
#  ('Nam Dinh', Decimal('3.99')),
#  ('Suihua', Decimal('4.99')),
#  ('Tanshui', Decimal('6.99')),
#  ('Bellevue', Decimal('4.99')),
#  ('Tanshui', Decimal('3.99')),
#  ('Nam Dinh', Decimal('6.99')),
#  ('Bradford', Decimal('5.99')),
#  ('Laohekou', Decimal('4.99')),
#  ('Kamyin', Decimal('1.99')),
#  ('Chungho', Decimal('8.99')),
#  ('Arecibo', Decimal('5.99')),
#  ('Jurez', Decimal('2.99')),
#  ('Uijongbu', Decimal('0.99')),
#  ('Karnal', Decimal('7.99')),
#  ('Kursk', Decimal('8.99')),
#  ('Fuyu', Decimal('5.99')),
#  ('Kuwana', Decimal('8.99')),
#  ('Livorno', Decimal('4.99')),
#  ('Barcelona', Decimal('6.99')),
#  ('Lapu-Lapu', Decimal('0.99')),
#  ('Maring', Decimal('2.99')),
#  ('Ivanovo', Decimal('2.99')),
#  ('Ipoh', Decimal('6.99')),
#  ('Fukuyama', Decimal('5.99')),
#  ('Ipoh', Decimal('3.99')),
#  ('Namibe', Decimal('0.99')),
#  ('Salala', Decimal('6.99')),
#  ('Santa F', Decimal('2.99')),
#  ('Sullana', Decimal('2.99')),
#  ('Ambattur', Decimal('7.99')),
#  ('Elista', Decimal('1.99')),
#  ('Guadalajara', Decimal('5.99')),
#  ('Baybay', Decimal('4.99')),
#  ('Roanoke', Decimal('0.99')),
#  ('Benin City', Decimal('4.99')),
#  ('Battambang', Decimal('5.99')),
#  ('Rustenburg', Decimal('0.99')),
#  ('Halisahar', Decimal('3.99')),
#  ('Pune', Decimal('4.99')),
#  ('Nagaon', Decimal('5.99')),
#  ('Citt del Vaticano', Decimal('9.99')),
#  ('Adana', Decimal('0.99')),
#  ('Halisahar', Decimal('6.99')),
#  ('London', Decimal('5.99')),
#  ('Sirjan', Decimal('8.99')),
#  ('Taizz', Decimal('2.99')),
#  ('Angra dos Reis', Decimal('7.99')),
#  ('Ocumare del Tuy', Decimal('8.99')),
#  ('Tiefa', Decimal('4.99')),
#  ('Tanauan', Decimal('8.99')),
#  ('Chatsworth', Decimal('2.99')),
#  ('Hanoi', Decimal('4.99')),
#  ('Haldia', Decimal('4.99')),
#  ('Ibirit', Decimal('6.99')),
#  ('Iwatsuki', Decimal('0.99')),
#  ('Ibirit', Decimal('3.99')),
#  ('Sawhaj', Decimal('3.99')),
#  ('Ashdod', Decimal('1.99')),
#  ('Sawhaj', Decimal('6.99')),
#  ('Qomsheh', Decimal('4.99')),
#  ('Bamenda', Decimal('0.99')),
#  ('Vaduz', Decimal('4.99')),
#  ('Athenai', Decimal('2.99')),
#  ('Amroha', Decimal('1.99')),
#  ('Gaziantep', Decimal('2.99')),
#  ('Kamakura', Decimal('2.99')),
#  ('Smolensk', Decimal('6.99')),
#  ('Malm', Decimal('4.99')),
#  ('Sungai Petani', Decimal('5.99')),
#  ('Rampur', Decimal('4.99')),
#  ('Smolensk', Decimal('3.99')),
#  ('Yaound', Decimal('1.99')),
#  ('Zhezqazghan', Decimal('1.99')),
#  ('Oyo', Decimal('2.99')),
#  ('Nabereznyje Telny', Decimal('0.99')),
#  ('Juiz de Fora', Decimal('0.99')),
#  ('Alvorada', Decimal('2.99')),
#  ('Omdurman', Decimal('8.99')),
#  ('Uluberia', Decimal('1.99')),
#  ('Sanya', Decimal('9.99')),
#  ('Dayton', Decimal('0.99')),
#  ('South Hill', Decimal('1.99')),
#  ('Emeishan', Decimal('9.99')),
#  ('Talavera', Decimal('7.99')),
#  ('Otsu', Decimal('7.99')),
#  ('Gatineau', Decimal('9.99')),
#  ('Mexicali', Decimal('9.99')),
#  ('Mandaluyong', Decimal('9.99')),
#  ('Hubli-Dharwad', Decimal('10.99')),
#  ('Yingkou', Decimal('1.99')),
#  ('Belm', Decimal('5.99')),
#  ('Saint Louis', Decimal('5.99')),
#  ('Brindisi', Decimal('7.99')),
#  ('Tanza', Decimal('0.99')),
#  ('Effon-Alaiye', Decimal('8.99')),
#  ('Sokoto', Decimal('4.99')),
#  ('Cuautla', Decimal('7.99')),
#  ('Korolev', Decimal('1.99')),
#  ('Santa Brbara dOeste', Decimal('1.99')),
#  ('Haining', Decimal('4.99')),
#  ('Jalib al-Shuyukh', Decimal('7.99')),
#  ('Uttarpara-Kotrung', Decimal('3.99')),
#  ('Toulouse', Decimal('2.99')),
#  ('Kuching', Decimal('8.99')),
#  ('Kansas City', Decimal('2.99')),
#  ('Songkhla', Decimal('1.99')),
#  ('Uttarpara-Kotrung', Decimal('6.99')),
#  ('Ciparay', Decimal('5.99')),
#  ('Palghat (Palakkad)', Decimal('3.99')),
#  ('Karnal', Decimal('9.99')),
#  ('Jamalpur', Decimal('7.99')),
#  ('Halle/Saale', Decimal('0.99')),
#  ('Aden', Decimal('1.99')),
#  ('Rancagua', Decimal('3.99')),
#  ('Jos Azueta', Decimal('4.99')),
#  ('Rancagua', Decimal('6.99')),
#  ('Sousse', Decimal('8.99')),
#  ('Palghat (Palakkad)', Decimal('6.99')),
#  ('Baiyin', Decimal('1.99')),
#  ('Pingxiang', Decimal('5.99')),
#  ('Mosul', Decimal('3.99')),
#  ('al-Hawiya', Decimal('7.99')),
#  ('Rizhao', Decimal('4.99')),
#  ('Mosul', Decimal('6.99')),
#  ('Okayama', Decimal('6.99')),
#  ('Monclova', Decimal('5.99')),
#  ('Southend-on-Sea', Decimal('2.99')),
#  ('Pereira', Decimal('4.99')),
#  ('Okayama', Decimal('3.99')),
#  ('Parbhani', Decimal('4.99')),
#  ('Miyakonojo', Decimal('3.99')),
#  ('Guaruj', Decimal('4.99')),
#  ('Miyakonojo', Decimal('6.99')),
#  ('Valle de la Pascua', Decimal('5.99')),
#  ('Bhopal', Decimal('8.99')),
#  ('Leshan', Decimal('3.99')),
#  ('Leshan', Decimal('6.99')),
#  ('Touliu', Decimal('0.99')),
#  ('Shimoga', Decimal('7.99')),
#  ('Dundee', Decimal('2.99')),
#  ('Antofagasta', Decimal('4.99')),
#  ('Nagareyama', Decimal('7.99')),
#  ('Changhwa', Decimal('8.97')),
#  ('Zapopan', Decimal('0.99')),
#  ('Nuuk', Decimal('3.99')),
#  ('Charlotte Amalie', Decimal('5.99')),
#  ('Memphis', Decimal('8.99')),
#  ('Dadu', Decimal('8.99')),
#  ('Jaroslavl', Decimal('4.99')),
#  ('Nuuk', Decimal('6.99')),
#  ('So Bernardo do Campo', Decimal('10.99')),
#  ('Quilmes', Decimal('0.99')),
#  ('Plock', Decimal('5.99')),
#  ('Halifax', Decimal('4.99')),
#  ('Aparecida de Goinia', Decimal('0.00')),
#  ('Carmen', Decimal('6.99')),
#  ('Zhoushan', Decimal('2.99')),
#  ('Xintai', Decimal('10.99')),
#  ('Klerksdorp', Decimal('7.99')),
#  ('San Felipe de Puerto Plata', Decimal('5.99')),
#  ('Yantai', Decimal('10.99')),
#  ('Trshavn', Decimal('6.99')),
#  ('Maracabo', Decimal('5.99')),
#  ('Denizli', Decimal('4.99')),
#  ('Garden Grove', Decimal('5.99')),
#  ('Nanyang', Decimal('1.99')),
#  ('Rio Claro', Decimal('2.99')),
#  ('Cheju', Decimal('7.99')),
#  ('Mardan', Decimal('7.99')),
#  ('San Juan Bautista Tuxtepec', Decimal('7.99')),
#  ('Bchar', Decimal('5.99')),
#  ('Liaocheng', Decimal('3.99')),
#  ('Davao', Decimal('7.99')),
#  ('Bilbays', Decimal('2.99')),
#  ('Monywa', Decimal('4.99')),
#  ('Higashiosaka', Decimal('4.99')),
#  ('Emeishan', Decimal('7.99')),
#  ('Talavera', Decimal('9.99')),
#  ('Gatineau', Decimal('7.99')),
#  ('Baha Blanca', Decimal('0.99')),
#  ('Otsu', Decimal('9.99')),
#  ('Liepaja', Decimal('0.99')),
#  ('Mexicali', Decimal('7.99')),
#  ('Mandaluyong', Decimal('7.99')),
#  ('Tarlac', Decimal('6.99')),
#  ('Huixquilucan', Decimal('6.99')),
#  ('al-Qadarif', Decimal('4.99')),
#  ('Sucre', Decimal('4.99')),
#  ('Mukateve', Decimal('2.99')),
#  ('Enshi', Decimal('3.99')),
#  ('Bhilwara', Decimal('9.99')),
#  ('Tarlac', Decimal('3.99')),
#  ('Huixquilucan', Decimal('3.99')),
#  ('Faaa', Decimal('3.99')),
#  ('Florencia', Decimal('4.99')),
#  ('Faaa', Decimal('6.99')),
#  ('Hodeida', Decimal('5.99')),
#  ('Kisumu', Decimal('2.99')),
#  ('Naala-Porto', Decimal('3.99')),
#  ('Hidalgo', Decimal('4.99')),
#  ('Sultanbeyli', Decimal('7.99')),
#  ('Bern', Decimal('1.99')),
#  ('Vinh', Decimal('0.99')),
#  ('Naala-Porto', Decimal('6.99')),
#  ('Izumisano', Decimal('7.99')),
#  ('Santa Rosa', Decimal('8.99')),
#  ('Graz', Decimal('7.99')),
#  ('Toulon', Decimal('7.99')),
#  ('Luzinia', Decimal('1.99')),
#  ('Osmaniye', Decimal('8.99')),
#  ('Yinchuan', Decimal('0.99')),
#  ('Avellaneda', Decimal('5.98')),
#  ('Etawah', Decimal('3.99')),
#  ('Cabuyao', Decimal('8.99')),
#  ('Atlixco', Decimal('6.99')),
#  ('Dhaka', Decimal('4.99')),
#  ('Atlixco', Decimal('3.99')),
#  ('York', Decimal('4.99')),
#  ('Lilongwe', Decimal('8.99')),
#  ('Etawah', Decimal('6.99')),
#  ('Jining', Decimal('3.99')),
#  ('Gandhinagar', Decimal('9.99')),
#  ('Jining', Decimal('6.99')),
#  ('Varanasi (Benares)', Decimal('0.99')),
#  ('Uruapan', Decimal('1.99')),
#  ('Idfu', Decimal('8.99')),
#  ('Nukualofa', Decimal('2.99')),
#  ('Almirante Brown', Decimal('2.99')),
#  ('Teboksary', Decimal('1.99')),
#  ('Jastrzebie-Zdrj', Decimal('5.99')),
#  ('Vitria de Santo Anto', Decimal('4.99')),
#  ('Tafuna', Decimal('7.99')),
#  ('Datong', Decimal('10.99')),
#  ('Grand Prairie', Decimal('0.99')),
#  ('Najafabad', Decimal('5.99')),
#  ('Molodetno', Decimal('4.99')),
#  ('Apeldoorn', Decimal('0.99')),
#  ('Tambaram', Decimal('1.99')),
#  ('Araatuba', Decimal('6.99')),
#  ('Lancaster', Decimal('8.99')),
#  ('Shenzhen', Decimal('3.99')),
#  ('Le Mans', Decimal('2.99')),
#  ('Duisburg', Decimal('2.99')),
#  ('Bijapur', Decimal('5.99')),
#  ('Araatuba', Decimal('3.99')),
#  ('Hino', Decimal('0.99')),
#  ('Mahajanga', Decimal('5.99')),
#  ('Ezhou', Decimal('5.99')),
#  ('Esfahan', Decimal('4.99')),
#  ('Junan', Decimal('0.99')),
#  ('Beni-Mellal', Decimal('2.99')),
#  ('Anpolis', Decimal('3.99')),
#  ('Botosani', Decimal('4.99')),
#  ('Sogamoso', Decimal('3.99')),
#  ('Saint-Denis', Decimal('10.99')),
#  ('Citt del Vaticano', Decimal('7.99')),
#  ('Hohhot', Decimal('3.99')),
#  ('Sogamoso', Decimal('6.99')),
#  ('Chungho', Decimal('7.99')),
#  ('Daxian', Decimal('5.99')),
#  ('Vancouver', Decimal('5.99')),
#  ('Gulbarga', Decimal('0.99')),
#  ('Kuching', Decimal('9.99')),
#  ('Karnal', Decimal('8.99')),
#  ('Poos de Caldas', Decimal('7.99')),
#  ('Udaipur', Decimal('0.99')),
#  ('Iwakuni', Decimal('5.99')),
#  ('Bhusawal', Decimal('0.99')),
#  ('Effon-Alaiye', Decimal('9.99')),
#  ('Stockport', Decimal('5.99')),
#  ('Tabriz', Decimal('5.99')),
#  ('Probolinggo', Decimal('10.99')),
#  ('Mannheim', Decimal('1.99')),
#  ('Qomsheh', Decimal('2.99')),
#  ('Vaduz', Decimal('2.99')),
#  ('Pemalang', Decimal('6.99')),
#  ('Athenai', Decimal('4.99')),
#  ('Pemalang', Decimal('3.99')),
#  ('Valle de Santiago', Decimal('5.99')),
#  ('Kalisz', Decimal('9.99')),
#  ('Siegen', Decimal('7.99')),
#  ('Gaziantep', Decimal('4.99')),
#  ('Pudukkottai', Decimal('5.99')),
#  ('Sanaa', Decimal('6.99')),
#  ('Kamakura', Decimal('4.99')),
#  ('Jakarta', Decimal('1.99')),
#  ('Malm', Decimal('2.99')),
#  ('Rampur', Decimal('2.99')),
#  ('Pyongyang', Decimal('5.99')),
#  ('Allappuzha (Alleppey)', Decimal('3.98')),
#  ('Sanaa', Decimal('3.99')),
#  ('Oyo', Decimal('4.99')),
#  ('Alvorada', Decimal('4.99')),
#  ('Rae Bareli', Decimal('6.99')),
#  ('Sambhal', Decimal('5.99')),
#  ('Memphis', Decimal('9.99')),
#  ('San Miguel de Tucumn', Decimal('5.99')),
#  ('Rae Bareli', Decimal('3.99')),
#  ('Bislig', Decimal('0.99')),
#  ('Chapra', Decimal('0.99')),
#  ('Avellaneda', Decimal('7.99')),
#  ('Fontana', Decimal('9.99')),
#  ('Kamarhati', Decimal('9.99')),
#  ('Taizz', Decimal('4.99')),
#  ('La Romana', Decimal('1.99')),
#  ('A Corua (La Corua)', Decimal('1.99')),
#  ('Tiefa', Decimal('2.99')),
#  ('Merlo', Decimal('0.99')),
#  ('Chatsworth', Decimal('4.99')),
#  ('Balikesir', Decimal('1.99')),
#  ('Hanoi', Decimal('2.99')),
#  ('Urawa', Decimal('5.99')),
#  ('Haldia', Decimal('2.99')),
#  ('Hagonoy', Decimal('7.99')),
#  ('Pavlodar', Decimal('1.99')),
#  ('Deba Habe', Decimal('8.99')),
#  ('Laiwu', Decimal('3.99')),
#  ('Ivanovo', Decimal('4.99')),
#  ('Portoviejo', Decimal('0.99')),
#  ('Jinzhou', Decimal('3.99')),
#  ('Funafuti', Decimal('5.99')),
#  ('Maring', Decimal('4.99')),
#  ('Jinzhou', Decimal('6.99')),
#  ('Sasebo', Decimal('1.99')),
#  ('Ourense (Orense)', Decimal('3.99')),
#  ('Ziguinchor', Decimal('8.99')),
#  ('Munger (Monghyr)', Decimal('0.99')),
#  ('Ourense (Orense)', Decimal('6.99')),
#  ('Cuman', Decimal('8.99')),
#  ('Miraj', Decimal('6.99')),
#  ('Kilis', Decimal('5.99')),
#  ('Sullana', Decimal('4.99')),
#  ('Santa F', Decimal('4.99')),
#  ('Yerevan', Decimal('0.99')),
#  ('Miraj', Decimal('3.99')),
#  ('Lengshuijiang', Decimal('1.99')),
#  ('Benin City', Decimal('2.99')),
#  ('Baybay', Decimal('2.99')),
#  ('Valencia', Decimal('3.99')),
#  ('Pune', Decimal('2.99')),
#  ('Tama', Decimal('8.99')),
#  ('Salinas', Decimal('1.99')),
#  ('Surakarta', Decimal('0.99')),
#  ('Valencia', Decimal('6.99')),
#  ('Laohekou', Decimal('2.99')),
#  ('Fuzhou', Decimal('1.99')),
#  ('Yamuna Nagar', Decimal('5.99')),
#  ('Bhilwara', Decimal('8.99')),
#  ('Brindisi', Decimal('8.99')),
#  ('Kanazawa', Decimal('1.99')),
#  ('Szkesfehrvr', Decimal('1.99')),
#  ('Balaiha', Decimal('9.99')),
#  ('Omdurman', Decimal('7.99')),
#  ('Coquimbo', Decimal('8.99')),
#  ('Kakamigahara', Decimal('0.99')),
#  ('Jurez', Decimal('4.99')),
#  ('Tonghae', Decimal('3.99')),
#  ('Ozamis', Decimal('7.99')),
#  ('Otsu', Decimal('8.99')),
#  ('Bratislava', Decimal('5.99')),
#  ('Tonghae', Decimal('6.99')),
#  ('Livorno', Decimal('2.99')),
#  ('Salzburg', Decimal('5.99')),
#  ('Osmaniye', Decimal('9.99')),
#  ('El Monte', Decimal('5.99')),
#  ('Springs', Decimal('5.99')),
#  ('Allende', Decimal('4.99')),
#  ('Cabuyao', Decimal('9.99')),
#  ('Celaya', Decimal('0.99')),
#  ('Sharja', Decimal('6.99')),
#  ('Boksburg', Decimal('2.99')),
#  ('Tarsus', Decimal('4.99')),
#  ('Tuguegarao', Decimal('5.99')),
#  ('Pontianak', Decimal('1.99')),
#  ('Sharja', Decimal('3.99')),
#  ('Tsuyama', Decimal('6.99')),
#  ('Crdoba', Decimal('5.99')),
#  ('Adoni', Decimal('3.99')),
#  ('Zalantun', Decimal('2.99')),
#  ('Adoni', Decimal('6.99')),
#  ('al-Ayn', Decimal('1.99')),
#  ('Suihua', Decimal('2.99')),
#  ('Bellevue', Decimal('2.99')),
#  ('Santa Rosa', Decimal('9.99')),
#  ('Warren', Decimal('0.99')),
#  ('Ocumare del Tuy', Decimal('7.99')),
#  ('Ahmadnagar', Decimal('10.99')),
#  ('Tanauan', Decimal('7.99')),
#  ('La Paz', Decimal('5.99')),
#  ('Saarbrcken', Decimal('2.99')),
#  ('al-Qatif', Decimal('2.99')),
#  ('Purnea (Purnia)', Decimal('5.99')),
#  ('Patras', Decimal('4.99')),
#  ('Mysore', Decimal('5.99')),
#  ('Skikda', Decimal('6.99')),
#  ('Kitwe', Decimal('5.99')),
#  ('Braslia', Decimal('2.99')),
#  ('Shanwei', Decimal('1.99')),
#  ('Ondo', Decimal('0.99')),
#  ('Skikda', Decimal('3.99')),
#  ('Naju', Decimal('0.99')),
#  ('Sirjan', Decimal('7.99')),
#  ('Tongliao', Decimal('2.99')),
#  ('Hami', Decimal('7.99')),
#  ('Onomichi', Decimal('0.99')),
#  ('Iwaki', Decimal('4.99')),
#  ('Kragujevac', Decimal('1.99')),
#  ('Pangkal Pinang', Decimal('4.99')),
#  ('Lublin', Decimal('5.99')),
#  ('Lausanne', Decimal('0.99')),
#  ('Bag', Decimal('4.99')),
#  ('Tete', Decimal('5.99')),
#  ('Pak Kret', Decimal('0.00')),
#  ('Jhansi', Decimal('2.99')),
#  ('Zaria', Decimal('6.99')),
#  ('Purwakarta', Decimal('0.99')),
#  ('Zaria', Decimal('3.99')),
#  ('Cheju', Decimal('8.99')),
#  ('Esfahan', Decimal('2.99')),
#  ('Beni-Mellal', Decimal('4.99')),
#  ('Sal', Decimal('0.99')),
#  ('Binzhou', Decimal('0.99')),
#  ('San Juan Bautista Tuxtepec', Decimal('8.99')),
#  ('Baicheng', Decimal('3.99')),
#  ('Baicheng', Decimal('6.99')),
#  ('Botosani', Decimal('2.99')),
#  ('Benguela', Decimal('3.99')),
#  ('Hsichuh', Decimal('1.99')),
#  ('Benguela', Decimal('6.99')),
#  ('Qinhuangdao', Decimal('5.99')),
#  ('Torren', Decimal('1.99')),
#  ('Memphis', Decimal('7.99')),
#  ('Dadu', Decimal('7.99')),
#  ('Asuncin', Decimal('5.99')),
#  ('Czestochowa', Decimal('7.99')),
#  ('Manchester', Decimal('1.99')),
#  ('Yangor', Decimal('6.99')),
#  ('Stara Zagora', Decimal('1.99')),
#  ('Nukualofa', Decimal('4.99')),
#  ('Fontana', Decimal('7.99')),
#  ('Almirante Brown', Decimal('4.99')),
#  ('Avellaneda', Decimal('9.99')),
#  ('Arlington', Decimal('11.99')),
#  ('Yangor', Decimal('3.99')),
#  ('Kamarhati', Decimal('7.99')),
#  ('Atinsk', Decimal('0.99')),
#  ('Vitria de Santo Anto', Decimal('2.99')),
#  ('Ikerre', Decimal('0.99')),
#  ('Bhopal', Decimal('7.99')),
#  ('Pathankot', Decimal('7.99')),
#  ('Molodetno', Decimal('2.99')),
#  ('Witten', Decimal('1.99')),
#  ('Balurghat', Decimal('1.99')),
#  ('Le Mans', Decimal('4.99')),
#  ('Nyeri', Decimal('9.99')),
#  ('Chisinau', Decimal('3.99')),
#  ('Shimoga', Decimal('8.99')),
#  ('Chisinau', Decimal('6.99')),
#  ('Duisburg', Decimal('4.99')),
#  ('Taguig', Decimal('0.99')),
#  ('Kisumu', Decimal('4.99')),
#  ('Ktahya', Decimal('6.99')),
#  ('Hidalgo', Decimal('2.99')),
#  ('Ciomas', Decimal('0.99')),
#  ('Ktahya', Decimal('3.99')),
#  ('Kaliningrad', Decimal('3.99')),
#  ('Kaliningrad', Decimal('6.99')),
#  ('Kalisz', Decimal('7.99')),
#  ('Banjul', Decimal('0.99')),
#  ('Lincoln', Decimal('0.99')),
#  ('Dhaka', Decimal('2.99')),
#  ('York', Decimal('2.99')),
#  ('So Leopoldo', Decimal('9.99')),
#  ('Monywa', Decimal('2.99')),
#  ('Higashiosaka', Decimal('2.99')),
#  ('Bilbays', Decimal('4.99')),
#  ('Kuching', Decimal('7.99')),
#  ('Gingoog', Decimal('5.99')),
#  ('s-Hertogenbosch', Decimal('9.99')),
#  ('Brockton', Decimal('5.99')),
#  ('Jamalpur', Decimal('8.99')),
#  ('Kursk', Decimal('9.99')),
#  ('Sousse', Decimal('7.99')),
#  ('Xiangtan', Decimal('0.99')),
#  ('Shimonoseki', Decimal('1.99')),
#  ('al-Qadarif', Decimal('2.99')),
#  ('Sucre', Decimal('2.99')),
#  ('Mukateve', Decimal('4.99')),
#  ('Southampton', Decimal('5.99')),
#  ('Florencia', Decimal('2.99')),
#  ('Novi Sad', Decimal('8.99')),
#  ('Baku', Decimal('6.99')),
#  ('Zhoushan', Decimal('4.99')),
#  ('Santo Andr', Decimal('5.99')),
#  ('Olomouc', Decimal('1.99')),
#  ('Amersfoort', Decimal('0.99')),
#  ('Ede', Decimal('0.99')),
#  ('Baku', Decimal('3.99')),
#  ('Citt del Vaticano', Decimal('8.99')),
#  ('Po', Decimal('3.99')),
#  ('Denizli', Decimal('2.99')),
#  ('Rio Claro', Decimal('4.99')),
#  ('Po', Decimal('6.99')),
#  ('Zanzibar', Decimal('3.99')),
#  ('Meixian', Decimal('5.99')),
#  ('Lancaster', Decimal('7.99')),
#  ('Dundee', Decimal('4.99')),
#  ('Jaipur', Decimal('3.99')),
#  ('Antofagasta', Decimal('2.99')),
#  ('Kermanshah', Decimal('10.99')),
#  ('Jaroslavl', Decimal('2.99')),
#  ('Zeleznogorsk', Decimal('7.99')),
#  ('Sagamihara', Decimal('6.99')),
#  ('Halifax', Decimal('2.99')),
#  ('Santo Andr', Decimal('7.98')),
#  ('Rockford', Decimal('3.98')),
#  ('Bhimavaram', Decimal('1.99')),
#  ('Osmaniye', Decimal('7.99')),
#  ('Jedda', Decimal('5.99')),
#  ('Cabuyao', Decimal('7.99')),
#  ('Tokat', Decimal('1.99')),
#  ('Kingstown', Decimal('7.99')),
#  ('Callao', Decimal('3.99')),
#  ('Callao', Decimal('6.99')),
#  ('Rizhao', Decimal('2.99')),
#  ('Buenaventura', Decimal('5.99')),
#  ('Lilongwe', Decimal('7.99')),
#  ('Lima', Decimal('0.99')),
#  ('Southend-on-Sea', Decimal('4.99')),
#  ('Pereira', Decimal('2.99')),
#  ('Parbhani', Decimal('2.99')),
#  ('El Fuerte', Decimal('3.99')),
#  ('Guaruj', Decimal('2.99')),
#  ('Santa Rosa', Decimal('7.99')),
#  ('El Fuerte', Decimal('6.99')),
#  ('Graz', Decimal('8.99')),
#  ('Cianjur', Decimal('5.99')),
#  ('Coacalco de Berriozbal', Decimal('1.99')),
#  ('Santiago de los Caballeros', Decimal('1.99')),
#  ('Sokoto', Decimal('2.99')),
#  ('Satna', Decimal('5.99')),
#  ('Haining', Decimal('2.99')),
#  ('Omdurman', Decimal('9.99')),
#  ('Toulouse', Decimal('4.99')),
#  ('Balaiha', Decimal('7.99')),
#  ('Davao', Decimal('8.99')),
#  ('Kansas City', Decimal('4.99')),
#  ('Emeishan', Decimal('8.99')),
#  ('Lubumbashi', Decimal('6.99')),
#  ('Ozamis', Decimal('9.99')),
#  ('Laredo', Decimal('0.99')),
#  ('Mexicali', Decimal('8.99')),
#  ('Jos Azueta', Decimal('2.99')),
#  ('Lubumbashi', Decimal('3.99')),
#  ('Mandaluyong', Decimal('8.99')),
#  ('Bandar Seri Begawan', Decimal('2.99')),
#  ('Czestochowa', Decimal('0.99')),
#  ('Bag', Decimal('5.99')),
#  ('Dadu', Decimal('0.99')),
#  ('Memphis', Decimal('0.99')),
#  ('Fontana', Decimal('0.99')),
#  ('Tete', Decimal('4.99')),
#  ('Kamarhati', Decimal('0.99')),
#  ('Quilmes', Decimal('8.99')),
#  ('Pathankot', Decimal('0.99')),
#  ('Johannesburg', Decimal('3.99')),
#  ('Novoterkassk', Decimal('6.99')),
#  ('Kaduna', Decimal('1.99')),
#  ('Erlangen', Decimal('2.99')),
#  ('Xintai', Decimal('1.99')),
#  ('Bhopal', Decimal('0.99')),
#  ('Novoterkassk', Decimal('3.99')),
#  ('al-Manama', Decimal('6.99')),
#  ('Iwaki', Decimal('5.99')),
#  ('Dos Quebradas', Decimal('1.99')),
#  ('Zapopan', Decimal('8.99')),
#  ('Lhokseumawe', Decimal('1.99')),
#  ('Pangkal Pinang', Decimal('5.99')),
#  ('Lublin', Decimal('4.99')),
#  ('Sorocaba', Decimal('0.99')),
#  ('Hiroshima', Decimal('1.99')),
#  ('al-Manama', Decimal('3.99')),
#  ('Faaa', Decimal('0.00')),
#  ('Kitwe', Decimal('4.99')),
#  ('Shikarpur', Decimal('2.99')),
#  ('Cam Ranh', Decimal('2.99')),
#  ('Sal', Decimal('7.99')),
#  ('So Bernardo do Campo', Decimal('1.99')),
#  ('Binzhou', Decimal('7.99')),
#  ('Munger (Monghyr)', Decimal('9.99')),
#  ('Alessandria', Decimal('2.99')),
#  ('Okinawa', Decimal('1.99')),
#  ('La Paz', Decimal('4.99')),
#  ('Yerevan', Decimal('9.99')),
#  ('Addis Abeba', Decimal('6.99')),
#  ('Purnea (Purnia)', Decimal('4.99')),
#  ('Mysore', Decimal('4.99')),
#  ('Kuching', Decimal('0.99')),
#  ('Crdoba', Decimal('4.99')),
#  ('Wroclaw', Decimal('6.99')),
#  ('Wroclaw', Decimal('3.99')),
#  ('Bergamo', Decimal('2.99')),
#  ('Sousse', Decimal('0.99')),
#  ('Xiangtan', Decimal('7.99')),
#  ('Udaipur', Decimal('9.99')),
#  ('Halle/Saale', Decimal('8.99')),
#  ('Bradford', Decimal('2.99')),
#  ('Tanza', Decimal('8.99')),
#  ('Salzburg', Decimal('4.99')),
#  ('El Monte', Decimal('4.99')),
#  ('Berhampore (Baharampur)', Decimal('2.99')),
#  ('Effon-Alaiye', Decimal('0.99')),
#  ('Daugavpils', Decimal('6.99')),
#  ('Daugavpils', Decimal('3.99')),
#  ('Springs', Decimal('4.99')),
#  ('Allende', Decimal('5.99')),
#  ('Paarl', Decimal('3.99')),
#  ('Tuguegarao', Decimal('4.99')),
#  ('Tarsus', Decimal('5.99')),
#  ('Paarl', Decimal('6.99')),
#  ('Salamanca', Decimal('1.99')),
#  ('Ciomas', Decimal('7.99')),
#  ('Songkhla', Decimal('10.99')),
#  ('Arecibo', Decimal('2.99')),
#  ('Jurez', Decimal('5.99')),
#  ('Usak', Decimal('1.99')),
#  ('Bratislava', Decimal('4.99')),
#  ('Kalisz', Decimal('0.99')),
#  ('Fuyu', Decimal('2.99')),
#  ('Kirovo-Tepetsk', Decimal('6.99')),
#  ('Yamuna Nagar', Decimal('4.99')),
#  ('Firozabad', Decimal('1.99')),
#  ('Banjul', Decimal('7.99')),
#  ('Kirovo-Tepetsk', Decimal('3.99')),
#  ('Jelets', Decimal('1.99')),
#  ('Lincoln', Decimal('7.99')),
#  ('Santa Brbara dOeste', Decimal('10.99')),
#  ('Kilis', Decimal('4.99')),
#  ('Santa F', Decimal('5.99')),
#  ('Sullana', Decimal('5.99')),
#  ('Apeldoorn', Decimal('8.99')),
#  ('Guadalajara', Decimal('2.99')),
#  ('Battambang', Decimal('2.99')),
#  ('Lungtan', Decimal('6.99')),
#  ('Saint-Denis', Decimal('1.99')),
#  ('Nagaon', Decimal('2.99')),
#  ('Cayenne', Decimal('1.99')),
#  ('Lancaster', Decimal('0.99')),
#  ('Syrakusa', Decimal('10.99')),
#  ('Tartu', Decimal('3.99')),
#  ('Usolje-Sibirskoje', Decimal('3.99')),
#  ('Funafuti', Decimal('4.99')),
#  ('Maring', Decimal('5.99')),
#  ('Ondo', Decimal('9.99')),
#  ('Usolje-Sibirskoje', Decimal('6.99')),
#  ('Serpuhov', Decimal('10.99')),
#  ('Tartu', Decimal('6.99')),
#  ('Fukuyama', Decimal('2.99')),
#  ('Varanasi (Benares)', Decimal('8.99')),
#  ('Zeleznogorsk', Decimal('0.99')),
#  ('Idfu', Decimal('0.99')),
#  ('Ede', Decimal('7.99')),
#  ('Zaoyang', Decimal('1.99')),
#  ('Chatsworth', Decimal('5.99')),
#  ('Urawa', Decimal('4.99')),
#  ('Datong', Decimal('1.99')),
#  ('Mandi Bahauddin', Decimal('3.99')),
#  ('Hoshiarpur', Decimal('3.99')),
#  ('El Alto', Decimal('6.99')),
#  ('Hoshiarpur', Decimal('6.99')),
#  ('Allappuzha (Alleppey)', Decimal('1.99')),
#  ('Sambhal', Decimal('4.99')),
#  ('San Miguel de Tucumn', Decimal('4.99')),
#  ('London', Decimal('2.99')),
#  ('Patiala', Decimal('6.99')),
#  ('Cuernavaca', Decimal('6.99')),
#  ('Cuernavaca', Decimal('3.99')),
#  ('Patiala', Decimal('3.99')),
#  ('Junan', Decimal('8.99')),
#  ('Taizz', Decimal('5.99')),
#  ('Gorontalo', Decimal('3.99')),
#  ('Gijn', Decimal('3.99')),
#  ('Kamakura', Decimal('5.99')),
#  ('Sungai Petani', Decimal('2.99')),
#  ('Pyongyang', Decimal('4.99')),
#  ('Gijn', Decimal('6.99')),
#  ('Gorontalo', Decimal('6.99')),
#  ('Brest', Decimal('3.99')),
#  ('Oyo', Decimal('5.99')),
#  ('Brest', Decimal('6.99')),
#  ('Alvorada', Decimal('5.99')),
#  ('Ueda', Decimal('1.99')),
#  ('Bayugan', Decimal('0.99')),
#  ('Pjatigorsk', Decimal('1.99')),
#  ('Matsue', Decimal('0.99')),
#  ('Balaiha', Decimal('0.99')),
#  ('Shaoguan', Decimal('4.99')),
#  ('Liepaja', Decimal('8.99')),
#  ('Laredo', Decimal('7.99')),
#  ('Athenai', Decimal('5.99')),
#  ('Myingyan', Decimal('1.99')),
#  ('Changhwa', Decimal('1.99')),
#  ('Valle de Santiago', Decimal('4.99')),
#  ('Baha Blanca', Decimal('8.99')),
#  ('Pudukkottai', Decimal('4.99')),
#  ('Gaziantep', Decimal('5.99')),
#  ('Escobar', Decimal('4.99')),
#  ('Iwakuni', Decimal('4.99')),
#  ('Belm', Decimal('2.99')),
#  ('Aparecida de Goinia', Decimal('6.99')),
#  ('Aparecida de Goinia', Decimal('3.99')),
#  ('Saint Louis', Decimal('2.99')),
#  ('Osmaniye', Decimal('0.99')),
#  ('Tsaotun', Decimal('4.99')),
#  ('Yinchuan', Decimal('8.99')),
#  ('Stockport', Decimal('4.99')),
#  ('Lilongwe', Decimal('0.99')),
#  ('Cabuyao', Decimal('0.99')),
#  ('Kingstown', Decimal('0.99')),
#  ('Tabriz', Decimal('4.99')),
#  ('Lima', Decimal('7.99')),
#  ('Daxian', Decimal('4.99')),
#  ('Nezahualcyotl', Decimal('1.99')),
#  ('Vinh', Decimal('8.99')),
#  ('Vancouver', Decimal('4.99')),
#  ('Santa Rosa', Decimal('0.99')),
#  ('Salinas', Decimal('3.98')),
#  ('Toulouse', Decimal('5.99')),
#  ('Bat Yam', Decimal('6.99')),
#  ('Ciparay', Decimal('2.99')),
#  ('Aurora', Decimal('8.99')),
#  ('Siegen', Decimal('0.99')),
#  ('Cianjur', Decimal('4.99')),
#  ('Tianjin', Decimal('6.99')),
#  ('Tianjin', Decimal('3.99')),
#  ('Satna', Decimal('4.99')),
#  ('Akron', Decimal('6.99')),
#  ('So Leopoldo', Decimal('0.99')),
#  ('Akron', Decimal('3.99')),
#  ('Linz', Decimal('8.99')),
#  ('s-Hertogenbosch', Decimal('0.99')),
#  ('Monclova', Decimal('2.99')),
#  ('Chungho', Decimal('0.99')),
#  ('Southend-on-Sea', Decimal('5.99')),
#  ('Gulbarga', Decimal('7.99')),
#  ('Xiangtan', Decimal('9.99')),
#  ('Udaipur', Decimal('7.99')),
#  ('Poos de Caldas', Decimal('0.99')),
#  ('Kuwana', Decimal('0.99')),
#  ('San Lorenzo', Decimal('10.99')),
#  ('Uijongbu', Decimal('8.99')),
#  ('Kursk', Decimal('0.99')),
#  ('Jedda', Decimal('4.99')),
#  ('Pingxiang', Decimal('2.99')),
#  ('Batman', Decimal('1.99')),
#  ('Omiya', Decimal('1.99')),
#  ('Rockford', Decimal('1.99')),
#  ('Buenaventura', Decimal('4.99')),
#  ('Charlotte Amalie', Decimal('2.99')),
#  ('Kimchon', Decimal('8.99')),
#  ('Sumy', Decimal('3.99')),
#  ('Sumy', Decimal('6.99')),
#  ('Portoviejo', Decimal('7.99')),
#  ('Sal', Decimal('9.99')),
#  ('Binzhou', Decimal('9.99')),
#  ('Plock', Decimal('2.99')),
#  ('Valle de la Pascua', Decimal('2.99')),
#  ('Yerevan', Decimal('7.99')),
#  ('Meixian', Decimal('4.99')),
#  ('Surakarta', Decimal('7.99')),
#  ('Dundee', Decimal('5.99')),
#  ('Clarksville', Decimal('10.99')),
#  ('Maracabo', Decimal('2.99')),
#  ('Imus', Decimal('6.99')),
#  ('Sumqayit', Decimal('1.99')),
#  ('Imus', Decimal('3.99')),
#  ('Jinchang', Decimal('1.99')),
#  ('Garden Grove', Decimal('2.99')),
#  ('Rio Claro', Decimal('5.99')),
#  ('Tandil', Decimal('3.99')),
#  ('Avellaneda', Decimal('0.99')),
#  ('Konotop', Decimal('8.99')),
#  ('Tychy', Decimal('10.99')),
#  ('Abha', Decimal('8.99')),
#  ('Santo Andr', Decimal('4.99')),
#  ('NDjamna', Decimal('1.99')),
#  ('Maikop', Decimal('8.99')),
#  ('San Felipe de Puerto Plata', Decimal('2.99')),
#  ('Merlo', Decimal('7.99')),
#  ('Mwene-Ditu', Decimal('1.99')),
#  ('Brescia', Decimal('6.99')),
#  ('Greensboro', Decimal('1.99')),
#  ('Hagonoy', Decimal('0.99')),
#  ('Brescia', Decimal('3.99')),
#  ('Ponce', Decimal('2.99')),
#  ('Shivapuri', Decimal('1.99')),
#  ('Southampton', Decimal('4.99')),
#  ('Nabereznyje Telny', Decimal('8.99')),
#  ('Juiz de Fora', Decimal('8.99')),
#  ('Hodeida', Decimal('2.99')),
#  ('Batna', Decimal('3.99')),
#  ('Bchar', Decimal('2.99')),
#  ('Bilbays', Decimal('5.99')),
#  ('Botshabelo', Decimal('0.99')),
#  ('Changzhou', Decimal('4.99')),
#  ('Gingoog', Decimal('4.99')),
#  ('Brockton', Decimal('4.99')),
#  ('Phnom Penh', Decimal('4.99')),
#  ('Zhezqazghan', Decimal('10.99')),
#  ('Weifang', Decimal('1.99')),
#  ('Kisumu', Decimal('5.99')),
#  ('Beira', Decimal('3.99')),
#  ('Omdurman', Decimal('0.99')),
#  ('Kakamigahara', Decimal('7.99')),
#  ('Beira', Decimal('6.99')),
#  ('Ozamis', Decimal('0.99')),
#  ('Jastrzebie-Zdrj', Decimal('2.99')),
#  ('Matamoros', Decimal('6.99')),
#  ('Ede', Decimal('9.99')),
#  ('Hami', Decimal('0.99')),
#  ('Matamoros', Decimal('3.99')),
#  ('Najafabad', Decimal('2.99')),
#  ('Onomichi', Decimal('7.99')),
#  ('Le Mans', Decimal('5.99')),
#  ('Lausanne', Decimal('7.99')),
#  ('Eskisehir', Decimal('6.99')),
#  ('Duisburg', Decimal('5.99')),
#  ('Rustenburg', Decimal('8.99')),
#  ('Papeete', Decimal('1.99')),
#  ('Bijapur', Decimal('2.99')),
#  ('Asuncin', Decimal('4.99')),
#  ('Tabuk', Decimal('6.99')),
#  ('Namibe', Decimal('8.99')),
#  ('Nukualofa', Decimal('5.99')),
#  ('Almirante Brown', Decimal('5.99')),
#  ('Tabuk', Decimal('3.99')),
#  ('Lipetsk', Decimal('2.99')),
#  ('Xiangfan', Decimal('3.99')),
#  ('Ocumare del Tuy', Decimal('0.99')),
#  ('Xiangfan', Decimal('6.99')),
#  ('Tanauan', Decimal('0.99')),
#  ('Kowloon and New Kowloon', Decimal('6.99')),
#  ('Kowloon and New Kowloon', Decimal('3.99')),
#  ('Qinhuangdao', Decimal('4.99')),
#  ('Birgunj', Decimal('6.99')),
#  ('Mahajanga', Decimal('2.99')),
#  ('Ezhou', Decimal('2.99')),
#  ('Sirjan', Decimal('0.99')),
#  ('Beni-Mellal', Decimal('5.99')),
#  ('Pachuca de Soto', Decimal('1.99')),
#  ('Iwakuni', Decimal('2.99')),
#  ('Escobar', Decimal('2.99')),
#  ('Shimonoseki', Decimal('10.99')),
#  ('Belm', Decimal('4.99')),
#  ('Saint Louis', Decimal('4.99')),
#  ('Banjul', Decimal('8.99')),
#  ('Tsaotun', Decimal('2.99')),
#  ('Stockport', Decimal('2.99')),
#  ('Rajkot', Decimal('6.99')),
#  ('Lincoln', Decimal('8.99')),
#  ('Rajkot', Decimal('3.99')),
#  ('Tabriz', Decimal('2.99')),
#  ('al-Hawiya', Decimal('0.99')),
#  ('Daxian', Decimal('2.99')),
#  ('Ciomas', Decimal('8.99')),
#  ('Vancouver', Decimal('2.99')),
#  ('Yuncheng', Decimal('1.99')),
#  ('Jaipur', Decimal('0.00')),
#  ('Tanza', Decimal('7.99')),
#  ('Sungai Petani', Decimal('4.99')),
#  ('Malm', Decimal('5.99')),
#  ('Rampur', Decimal('5.99')),
#  ('Pyongyang', Decimal('2.99')),
#  ('Kimberley', Decimal('6.99')),
#  ('Cuautla', Decimal('0.99')),
#  ('Jodhpur', Decimal('1.99')),
#  ('Jalib al-Shuyukh', Decimal('0.99')),
#  ('Shaoguan', Decimal('2.99')),
#  ('Qomsheh', Decimal('5.99')),
#  ('Xiangtan', Decimal('8.99')),
#  ('Kanchrapara', Decimal('6.99')),
#  ('Hamilton', Decimal('6.99')),
#  ('Vaduz', Decimal('5.99')),
#  ('Jamalpur', Decimal('0.99')),
#  ('Halle/Saale', Decimal('7.99')),
#  ('Hamilton', Decimal('3.99')),
#  ('Valle de Santiago', Decimal('2.99')),
#  ('Pudukkottai', Decimal('2.99')),
#  ('Tiefa', Decimal('5.99')),
#  ('Klerksdorp', Decimal('0.99')),
#  ('Basel', Decimal('9.99')),
#  ('Hanoi', Decimal('5.99')),
#  ('Tieli', Decimal('1.99')),
#  ('Urawa', Decimal('2.99')),
#  ('Haldia', Decimal('5.99')),
#  ('Syktyvkar', Decimal('0.99')),
#  ('Sambhal', Decimal('2.99')),
#  ('Purwakarta', Decimal('8.99')),
#  ('San Miguel de Tucumn', Decimal('2.99')),
#  ('London', Decimal('4.99')),
#  ('Citrus Heights', Decimal('9.99')),
#  ('Mardan', Decimal('0.99')),
#  ('Sal', Decimal('8.99')),
#  ('San Juan Bautista Tuxtepec', Decimal('0.99')),
#  ('Binzhou', Decimal('8.99')),
#  ('Cheju', Decimal('0.99')),
#  ('Ife', Decimal('1.99')),
#  ('Yaound', Decimal('3.98')),
#  ('Kilis', Decimal('2.99')),
#  ('Guadalajara', Decimal('4.99')),
#  ('Ogbomosho', Decimal('0.99')),
#  ('Baybay', Decimal('5.99')),
#  ('Battambang', Decimal('4.99')),
#  ('Benin City', Decimal('5.99')),
#  ('Nagareyama', Decimal('0.99')),
#  ('Pune', Decimal('5.99')),
#  ('Nagaon', Decimal('4.99')),
#  ('Touliu', Decimal('7.99')),
#  ('Shimoga', Decimal('0.99')),
#  ('Sincelejo', Decimal('3.99')),
#  ('Funafuti', Decimal('2.99')),
#  ('Abha', Decimal('9.99')),
#  ('Fukuyama', Decimal('4.99')),
#  ('Quilmes', Decimal('7.99')),
#  ('Sunnyvale', Decimal('1.99')),
#  ('Sultanbeyli', Decimal('0.99')),
#  ('Vinh', Decimal('7.99')),
#  ('Niznekamsk', Decimal('1.99')),
#  ('Arecibo', Decimal('4.99')),
#  ('Graz', Decimal('0.99')),
#  ('Bratislava', Decimal('2.99')),
#  ('Toulon', Decimal('0.99')),
#  ('Fuyu', Decimal('4.99')),
#  ('Izumisano', Decimal('0.99')),
#  ('Livorno', Decimal('5.99')),
#  ('Laohekou', Decimal('5.99')),
#  ('Udine', Decimal('3.99')),
#  ('Yamuna Nagar', Decimal('2.99')),
#  ('Jaipur', Decimal('9.98')),
#  ('Yinchuan', Decimal('7.99')),
#  ('Jaffna', Decimal('1.99')),
#  ...]

# %% [markdown]
# ### 3.2.2 Top grossing cities
# TODO: Write a query that returns the total amount of revenue by city as measured by the `amount` variable in the `payment` table. Limit the results to the top 10 cities. Your result should match the table below.

# %%
# %%sql
# SELECT ci.city, SUM(p.amount) as revenue
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# GROUP BY ci.city
# ORDER BY revenue DESC
# LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Cape Coral', Decimal('221.55')),
#  ('Saint-Denis', Decimal('216.54')),
#  ('Aurora', Decimal('198.50')),
#  ('Molodetno', Decimal('195.58')),
#  ('Apeldoorn', Decimal('194.61')),
#  ('Santa Brbara dOeste', Decimal('194.61')),
#  ('Qomsheh', Decimal('186.62')),
#  ('London', Decimal('180.52')),
#  ('Ourense (Orense)', Decimal('177.60')),
#  ('Bijapur', Decimal('175.61'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>Cape Coral</td>
#         <td>221.55</td>
#     </tr>
#     <tr>
#         <td>Saint-Denis</td>
#         <td>216.54</td>
#     </tr>
#     <tr>
#         <td>Aurora</td>
#         <td>198.50</td>
#     </tr>
#     <tr>
#         <td>Molodetno</td>
#         <td>195.58</td>
#     </tr>
#     <tr>
#         <td>Apeldoorn</td>
#         <td>194.61</td>
#     </tr>
#     <tr>
#         <td>Santa Brbara dOeste</td>
#         <td>194.61</td>
#     </tr>
#     <tr>
#         <td>Qomsheh</td>
#         <td>186.62</td>
#     </tr>
#     <tr>
#         <td>London</td>
#         <td>180.52</td>
#     </tr>
#     <tr>
#         <td>Ourense (Orense)</td>
#         <td>177.60</td>
#     </tr>
#     <tr>
#         <td>Bijapur</td>
#         <td>175.61</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## 3.3 Insight 3 : Revenue of a movie by customer city and by month

# %% [markdown]
# ### 3.3.1 Total revenue by month

# %%
# %%sql
# SELECT sum(p.amount) as revenue, EXTRACT(month FROM p.payment_date) as month
# from payment p
# group by month
# order by revenue desc
# limit 10;

# %% [markdown]
# ### 3.3.2 Each movie by customer city and by month (data cube)

# %%
# %%sql
# SELECT f.title, p.amount, p.customer_id, ci.city, p.payment_date,EXTRACT(month FROM p.payment_date) as month
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;

# %% [markdown]
# ### 3.3.3 Sum of revenue of each movie by customer city and by month
#
# TODO: Write a query that returns the total amount of revenue for each movie by customer city and by month. Limit the results to the top 10 movies. Your result should match the table below.

# %%
# %%sql
# SELECT f.title,  ci.city, EXTRACT(month FROM p.payment_date) as month, SUM(p.amount) as revenue
# FROM payment p
# JOIN rental r  ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# GROUP BY city, month, title
# ORDER BY month ASC,  revenue DESC, TITLE, city
# LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('SHOW LORD', 'Mannheim', 1.0, Decimal('11.99')),
#  ('AMERICAN CIRCUS', 'Callao', 1.0, Decimal('10.99')),
#  ('CASUALTIES ENCINO', 'Warren', 1.0, Decimal('10.99')),
#  ('KISSING DOLLS', 'Toulon', 1.0, Decimal('10.99')),
#  ('TELEGRAPH VOYAGE', 'Naala-Porto', 1.0, Decimal('10.99')),
#  ('AUTUMN CROW', 'Ashgabat', 1.0, Decimal('9.99')),
#  ('CALIFORNIA BIRDS', 'Plock', 1.0, Decimal('9.99')),
#  ('DARKO DORADO', 'Bhilwara', 1.0, Decimal('9.99')),
#  ('DAY UNFAITHFUL', 'Baybay', 1.0, Decimal('9.99')),
#  ('HEAD STRANGER', 'Xiangtan', 1.0, Decimal('9.99'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>title</th>
#         <th>city</th>
#         <th>month</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>SHOW LORD</td>
#         <td>Mannheim</td>
#         <td>1.0</td>
#         <td>11.99</td>
#     </tr>
#     <tr>
#         <td>AMERICAN CIRCUS</td>
#         <td>Callao</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>CASUALTIES ENCINO</td>
#         <td>Warren</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>TELEGRAPH VOYAGE</td>
#         <td>Naala-Porto</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>KISSING DOLLS</td>
#         <td>Toulon</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>MILLION ACE</td>
#         <td>Bergamo</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>TITANS JERK</td>
#         <td>Kimberley</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>DARKO DORADO</td>
#         <td>Bhilwara</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>SUNRISE LEAGUE</td>
#         <td>Nagareyama</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>MILLION ACE</td>
#         <td>Gaziantep</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
# </tbody></table></div>
